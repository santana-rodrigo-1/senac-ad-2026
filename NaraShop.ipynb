# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pedidos_narashop.csv', sep=';')
df
# Out:
#        pedido_id           vendedor         categoria  \
# 0          10001    Rafael Oliveira          Esportes
# 1          10002       Leandro Reis       Eletrônicos
# 2          10003     Flávia Azevedo       Eletrônicos
# 3          10004      Lucas Ribeiro          Esportes
# 4          10005     Vinícius Lopes       Eletrônicos
# ...          ...                ...               ...
# 19995      29996      Tatiane Cunha          Esportes
# 19996      29997           Ana Lima  Casa e Decoração
# 19997      29998     Patrícia Rocha       Eletrônicos
# 19998      29999  Alexandre Lacerda          Esportes
# 19999      30000      Thiago Santos  Casa e Decoração
#
#                        produto status_pedido  quantidade  valor_unitario  \
# 0      Raquete de Beach Tennis      Entregue           5           98.01
# 1                  SSD Externo      Entregue           4          599.89
# 2                     Notebook      Entregue           5         3774.96
# 3              Garrafa Térmica      Entregue           1           87.67
# 4                  SSD Externo      Entregue           3          439.02
# ...                        ...           ...         ...             ...
# 19995  Raquete de Beach Tennis      Entregue           4          178.86
# 19996              Tapete Sala   Em trânsito           4          166.27
# 19997                   Tablet     Cancelado           5         1577.65
# 19998        Bermuda Esportiva      Entregue           4          144.59
# 19999        Quadro Decorativo   Em trânsito           3           65.70
#
#        prazo_entrega_dias
# 0                      12
# 1                       8
# 2                       5
# 3                       4
# 4                       3
# ...                   ...
# 19995                   5
# 19996                   5
# 19997                   4
# 19998                   9
# 19999                  18
#
# [20000 rows x 8 columns]

# %%
df['valor_pedido'] = df['quantidade'] * df['valor_unitario']
df
# Out:
#        pedido_id           vendedor         categoria  \
# 0          10001    Rafael Oliveira          Esportes
# 1          10002       Leandro Reis       Eletrônicos
# 2          10003     Flávia Azevedo       Eletrônicos
# 3          10004      Lucas Ribeiro          Esportes
# 4          10005     Vinícius Lopes       Eletrônicos
# ...          ...                ...               ...
# 19995      29996      Tatiane Cunha          Esportes
# 19996      29997           Ana Lima  Casa e Decoração
# 19997      29998     Patrícia Rocha       Eletrônicos
# 19998      29999  Alexandre Lacerda          Esportes
# 19999      30000      Thiago Santos  Casa e Decoração
#
#                        produto status_pedido  quantidade  valor_unitario  \
# 0      Raquete de Beach Tennis      Entregue           5           98.01
# 1                  SSD Externo      Entregue           4          599.89
# 2                     Notebook      Entregue           5         3774.96
# 3              Garrafa Térmica      Entregue           1           87.67
# 4                  SSD Externo      Entregue           3          439.02
# ...                        ...           ...         ...             ...
# 19995  Raquete de Beach Tennis      Entregue           4          178.86
# 19996              Tapete Sala   Em trânsito           4          166.27
# 19997                   Tablet     Cancelado           5         1577.65
# 19998        Bermuda Esportiva      Entregue           4          144.59
# 19999        Quadro Decorativo   Em trânsito           3           65.70
#
#        prazo_entrega_dias  valor_pedido
# 0                      12        490.05
# 1                       8       2399.56
# 2                       5      18874.80
# 3                       4         87.67
# 4                       3       1317.06
# ...                   ...           ...
# 19995                   5        715.44
# 19996                   5        665.08
# 19997                   4       7888.25
# 19998                   9        578.36
# 19999                  18        197.10
#
# [20000 rows x 9 columns]

# %% [markdown]
# #### O gerente quer saber quais categorias geraram mais receita.
# #### Apresente o faturamento total por categoria, do maior para o menor.

# %%
df_total_categoria = df.groupby('categoria')['valor_pedido'].sum().reset_index()
df_total_categoria.sort_values(by='valor_pedido', ascending=False, inplace= True)
df_total_categoria
# Out:
#           categoria  valor_pedido
# 2       Eletrônicos   37037997.65
# 3          Esportes    8058234.35
# 1  Casa e Decoração    3333395.06
# 0        Brinquedos    2306126.65

# %% [markdown]
# ![{3E5E7E1F-8920-4859-A9CD-6DF0BE098002}.png](attachment:{3E5E7E1F-8920-4859-A9CD-6DF0BE098002}.png)

# %%
df_entregue_acima_500 = df.loc[(df['status_pedido'] == 'Entregue') & (df['valor_pedido'] > 500)]

df_entregue_acima_500II = df.query('status_pedido == "Entregue"' and 'valor_pedido > 500')
df_entregue_acima_500II
# Out:
#        pedido_id           vendedor         categoria  \
# 1          10002       Leandro Reis       Eletrônicos
# 2          10003     Flávia Azevedo       Eletrônicos
# 4          10005     Vinícius Lopes       Eletrônicos
# 5          10006    Diego Fernandes          Esportes
# 10         10011      Simone Castro       Eletrônicos
# ...          ...                ...               ...
# 19993      29994    Rafael Oliveira       Eletrônicos
# 19995      29996      Tatiane Cunha          Esportes
# 19996      29997           Ana Lima  Casa e Decoração
# 19997      29998     Patrícia Rocha       Eletrônicos
# 19998      29999  Alexandre Lacerda          Esportes
#
#                        produto status_pedido  quantidade  valor_unitario  \
# 1                  SSD Externo      Entregue           4          599.89
# 2                     Notebook      Entregue           5         3774.96
# 4                  SSD Externo      Entregue           3          439.02
# 5        Bicicleta Ergométrica   Em trânsito           2         1326.21
# 10                    Notebook   Em trânsito           1         3522.09
# ...                        ...           ...         ...             ...
# 19993                 Notebook   Em trânsito           1         5237.04
# 19995  Raquete de Beach Tennis      Entregue           4          178.86
# 19996              Tapete Sala   Em trânsito           4          166.27
# 19997                   Tablet     Cancelado           5         1577.65
# 19998        Bermuda Esportiva      Entregue           4          144.59
#
#        prazo_entrega_dias  valor_pedido
# 1                       8       2399.56
# 2                       5      18874.80
# 4                       3       1317.06
# 5                       8       2652.42
# 10                      9       3522.09
# ...                   ...           ...
# 19993                  10       5237.04
# 19995                   5        715.44
# 19996                   5        665.08
# 19997                   4       7888.25
# 19998                   9        578.36
#
# [13391 rows x 9 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_produto = df.groupby('produto')['valor_pedido'].sum().reset_index()
df_produto.sort_values(by='valor_pedido', ascending=False, inplace=True)
df_produto.head()
# Out:
#                   produto  valor_pedido
# 27               Notebook   15091721.74
# 37               Smart TV    8474171.95
# 38             Smartphone    6806241.19
# 1   Bicicleta Ergométrica    5949159.26
# 40                 Tablet    3258725.63

# %%
array_valor_produto = np.array(df_produto['valor_pedido'])
q1 = np.percentile(array_valor_produto, 25)
q3 = np.percentile(array_valor_produto, 75)
print(q1)
print(q3)
# Out:
# 73869.3475
# 367550.645

# %%
df_produto_25_mais = df_produto.loc[df_produto['valor_pedido'] > q3]
df_produto_25_mais
# Out:
#                   produto  valor_pedido
# 27               Notebook   15091721.74
# 37               Smart TV    8474171.95
# 38             Smartphone    6806241.19
# 1   Bicicleta Ergométrica    5949159.26
# 40                 Tablet    3258725.63
# 39             Smartwatch    1344856.80
# 13   Fritadeira Air Fryer     980636.15
# 17        Jogo de Panelas     760544.58
# 36            SSD Externo     719921.59
# 45       Tênis de Corrida     696912.40
# 44    Telescópio Infantil     409588.10
# 43       Teclado Mecânico     372827.72

# %%
df_produto_25_menos = df_produto.loc[df_produto['valor_pedido'] < q1]
df_produto_25_menos
# Out:
#                      produto  valor_pedido
# 0          Bermuda Esportiva      73266.61
# 8        Conjunto de Toalhas      70889.32
# 6        Carregador Portátil      64156.00
# 14           Garrafa Térmica      63532.51
# 10         Difusor de Aromas      57532.21
# 34  Quebra-Cabeça 1000 peças      51701.41
# 30                   Pelúcia      51088.67
# 42            Tapete de Yoga      50209.91
# 28    Organizador de Gavetas      36586.33
# 32            Porta-Retratos      26224.38
# 9             Corda de Pular      23767.20
# 24       Massinha de Modelar      17550.06

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
array_valor_pedido = np.array(df['valor_pedido'])
media = np.mean(array_valor_pedido)
mediana = np.median(array_valor_pedido)
distancia = (media - mediana) / mediana

print(f'A média é de {media}\nA Mediana é de {mediana}')
print(f'A distância entre a Média e a Mediana é de {distancia:.2%}')
# Out:
# A média é de 2536.7876855
# A Mediana é de 882.635
# A distância entre a Média e a Mediana é de 187.41%
