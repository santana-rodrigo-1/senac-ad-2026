# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

dados = {'vendedor' : ['Naruto' , 'Goku', 'Seiya'],
         'produto': ['Geladeira', 'Fogão', 'Ar Condicionado'],
         'vendas': [3400, 750, 2650]}

df = pd.DataFrame(dados)
#print (df) #python
#display (df) #jupyter
df
# Out:
#   vendedor          produto  vendas
# 0   Naruto        Geladeira    3400
# 1     Goku            Fogão     750
# 2    Seiya  Ar Condicionado    2650

# %%
dados = "https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv"
#dados = 'BaseDPEvolucaoMensalCisp.csv' # desatualizado sempre pegar novo se for o caso

df = pd.read_csv(dados, encoding='latin1', sep = ';') #ou latin-1#
df
#df.head
#df.head(15)
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 37583   159    3  2026  2026m03    35     4  Cachoeiras de Macacu  3300803
# 37584   165    3  2026  2026m03    33     5           Mangaratiba  3302601
# 37585   166    3  2026  2026m03    33     5        Angra dos Reis  3300100
# 37586   167    3  2026  2026m03    43     5                Paraty  3303807
# 37587   168    3  2026  2026m03    28     5             Rio Claro  3304409
#
# ...

# %%
df.tail()
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 37583   159    3  2026  2026m03    35     4  Cachoeiras de Macacu  3300803
# 37584   165    3  2026  2026m03    33     5           Mangaratiba  3302601
# 37585   166    3  2026  2026m03    33     5        Angra dos Reis  3300100
# 37586   167    3  2026  2026m03    43     5                Paraty  3303807
# 37587   168    3  2026  2026m03    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 37583  Interior           3  ...   5.0   0.0      26                      1
# 37584  Interior           1  ...  13.0   0.0      33                      1
# 37585  Interior           2  ...  14.0   1.0      91                     10
# 37586  Interior           0  ...   7.0   0.0      25                      1
# 37587  Interior           0  ...   1.0   0.0       8                      0
#
# ...

# %%
df.columns
# Out:
# Index(['cisp', 'mes', 'ano', 'mes_ano', 'aisp', 'risp', 'munic', 'mcirc',
#        'regiao', 'hom_doloso', 'lesao_corp_morte', 'latrocinio', 'cvli',
#        'hom_por_interv_policial', 'feminicidio', 'letalidade_violenta',
#        'tentat_hom', 'tentativa_feminicidio', 'lesao_corp_dolosa', 'estupro',
#        'hom_culposo', 'lesao_corp_culposa', 'roubo_transeunte',
#        'roubo_celular', 'roubo_em_coletivo', 'roubo_rua', 'roubo_veiculo',
#        'roubo_carga', 'roubo_comercio', 'roubo_residencia', 'roubo_banco',
#        'roubo_cx_eletronico', 'roubo_conducao_saque', 'roubo_apos_saque',
#        'roubo_bicicleta', 'outros_roubos', 'total_roubos', 'furto_veiculos',
#        'furto_transeunte', 'furto_coletivo', 'furto_celular',
#        'furto_bicicleta', 'outros_furtos', 'total_furtos', 'sequestro',
#        'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas',
#        'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor',
# ...

# %%
df.shape
# Out:
# (37588, 65)

# %%
df.dtypes
# Out:
# cisp                         int64
# mes                          int64
# ano                          int64
# mes_ano                        str
# aisp                         int64
#                              ...
# encontro_ossada              int64
# pol_militares_mortos_serv    int64
# pol_civis_mortos_serv        int64
# registro_ocorrencias         int64
# fase                         int64
# Length: 65, dtype: object

# %%
df.head()
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37588 entries, 0 to 37587
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cisp                        37588 non-null  int64
#  1   mes                         37588 non-null  int64
#  2   ano                         37588 non-null  int64
#  3   mes_ano                     37588 non-null  str
#  4   aisp                        37588 non-null  int64
#  5   risp                        37588 non-null  int64
#  6   munic                       37588 non-null  str
#  7   mcirc                       37588 non-null  int64
#  8   regiao                      37588 non-null  str
#  9   hom_doloso                  37588 non-null  int64
#  10  lesao_corp_morte            37588 non-null  int64
#  11  latrocinio                  37588 non-null  int64
#  12  cvli                        37588 non-null  int64
# ...

# %%
df.describe()
# Out:
#                cisp           mes           ano          aisp          risp  \
# count  37588.000000  37588.000000  37588.000000  37588.000000  37588.000000
# mean      81.724513      6.453203   2014.274822     20.152708      3.869932
# std       48.320601      3.465985      6.677154     11.350589      2.011415
# min        1.000000      1.000000   2003.000000      1.000000      1.000000
# 25%       38.000000      3.000000   2009.000000     10.000000      2.000000
# 50%       78.000000      6.000000   2014.000000     20.000000      4.000000
# 75%      125.000000      9.000000   2020.000000     30.000000      6.000000
# max      168.000000     12.000000   2026.000000     43.000000      7.000000
#
#               mcirc    hom_doloso  lesao_corp_morte    latrocinio  \
# count  3.758800e+04  37588.000000      37588.000000  37588.000000
# mean   3.791586e+06      2.916383          0.028227      0.095190
# std    1.740552e+06      4.318591          0.180091      0.365578
# ...

# %%
df.tail()
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 37583   159    3  2026  2026m03    35     4  Cachoeiras de Macacu  3300803
# 37584   165    3  2026  2026m03    33     5           Mangaratiba  3302601
# 37585   166    3  2026  2026m03    33     5        Angra dos Reis  3300100
# 37586   167    3  2026  2026m03    43     5                Paraty  3303807
# 37587   168    3  2026  2026m03    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 37583  Interior           3  ...   5.0   0.0      26                      1
# 37584  Interior           1  ...  13.0   0.0      33                      1
# 37585  Interior           2  ...  14.0   1.0      91                     10
# 37586  Interior           0  ...   7.0   0.0      25                      1
# 37587  Interior           0  ...   1.0   0.0       8                      0
#
# ...

# %%
df_furto_celular_cisp = df.groupby("cisp") ['furto_celular'].sum().reset_index()
df_furto_celular_cisp = df_furto_celular_cisp.sort_values(by="furto_celular", ascending=False)
df_furto_celular_cisp



# sempre o groupbu qualitatita e entre parenteses
# entre aspas quantitativa
#atualizaçãode varialvel e ela sofrendo alteração
# Out:
#      cisp  furto_celular
# 12     16          25709
# 2       5          24695
# 10     14          18286
# 8      12          16929
# 0       1          15952
# ..    ...            ...
# 87    104             72
# 77     92             65
# 114   138             55
# 131   157             55
# 129   155             47
#
# [138 rows x 2 columns]

# %%
df_aaapai_cisp = df.groupby("cisp") ['aaapai'].sum().reset_index()
df_aaapai_cisp = df_aaapai_cisp.sort_values(by="aaapai", ascending=False)
df_aaapai_cisp

#estou vendo qual tem mais aprrensão de menores
#ctrl+d selecionar tudo
# Out:
#      cisp  aaapai
# 104   126  3661.0
# 8      12  3655.0
# 10     14  3346.0
# 65     74  3343.0
# 12     16  3179.0
# ..    ...     ...
# 130   156    18.0
# 129   155    16.0
# 131   157    14.0
# 94    111    13.0
# 77     92    12.0
#
# [138 rows x 2 columns]

# %%
# estudar plano cartesiano , a logica dele é usada em aula
# olhar conceiro de mediana
# medida de tendencia central
# nunca use prvisão de dados , use predição , analise preditiva
# ver resetindex
# dataframe é de duas colunas para cima

# %%
#Usando .loc
df_capital = df.loc[df['munic'] == 'Rio de Janeiro']

#Usando .query() - sintaxe alternativa mais legível
#df_capital = df.query("munic == 'Rio de Janeiro'")

# repetindo o groupby apenas para a a capital
df_cisp_capital = df_capital.groupby('cisp')['furto_celular'].sum().reset_index()
df_cisp_capital = df_cisp_capital.sort_values(by="furto_celular", ascending=False)
df_cisp_capital
# Out:
#     cisp  furto_celular
# 12    16          25709
# 2      5          24695
# 10    14          18286
# 8     12          16929
# 0      1          15952
# 5      9          15009
# 6     10          14571
# 14    18          14047
# 1      4          13992
# 28    32          12623
# 31    35          12092
# 15    19           8717
# 13    17           8491
# 25    29           8023
# 38    42           7995
# 9     13           7532
# 19    23           7283
# 11    15           7109
# 17    21           6932
# 30    34           6907
# 33    37           6605
# 3      6           6526
# 29    33           6078
# 18    22           5714
# 32    36           5555
# 37    41           5405
# 16    20           5248
# 20    24           4673
# 23    27           4627
# 24    28           4067
# 21    25           4005
# 22    26           4001
# 40    44           3729
# 26    30           3726
# 34    38           3076
# 35    39           2899
# 39    43           2833
# ...

# %%
'''
ANOTAÇÃO:
numpy é otimizada cara calculo de grande volume de dados panda é mais lento
grande numero de dados é sempre em numpy

'''


# df_cisp_capital já foi criado no passo anterior (groupby + reset_index)
array_furto = np.array(df_cisp_capital['furto_celular'])

#print(array_furto)
array_furto
# Out:
# array([25709, 24695, 18286, 16929, 15952, 15009, 14571, 14047, 13992,
#        12623, 12092,  8717,  8491,  8023,  7995,  7532,  7283,  7109,
#         6932,  6907,  6605,  6526,  6078,  5714,  5555,  5405,  5248,
#         4673,  4627,  4067,  4005,  4001,  3729,  3726,  3076,  2899,
#         2833,  2301,  1702,  1578,   402,    73])

# %%
maximo = np.max(array_furto)
minimo = np.min(array_furto)
media = np.mean(array_furto)
mediana = np.median(array_furto)
q1 = np.percentile(array_furto, 25)
q2 = np.percentile(array_furto, 50)
q3 = np.percentile(array_furto, 75)
distancia = (media - mediana) / mediana
amplitude = maximo - minimo
#distancia = distancia * 100


print(f'O valor máximo é: {maximo}') # isto é um print formatado
print(f'O valor minimo é: {minimo}')
print(f'A Média é: {media}')
print(f'O Madiana é: {mediana}')
print(f'q1: {q1}')
print(f'q2: {q2}')
print(f'q3: {q3}')
#print(f'A Distância: {distancia:.2f}')
print(f'A Distância: {distancia:.2%}')
print(f"Amplitude: {amplitude:.2f}")
# Out:
# O valor máximo é: 25709
# O valor minimo é: 73
# A Média é: 8040.880952380952
# O Madiana é: 6565.5
# q1: 4002.0
# q2: 6565.5
# q3: 11248.25
# A Distância: 22.47%
# Amplitude: 25636.00

# %%
# Desenhando o Boxplot — horizontal com média

plt.figure(figsize=(10, 4)) # horizontal: largura maior que altura
plt.boxplot(array_furto, vert=False, showmeans=True)
plt.title('Distribuição do Valor de Pedido — NaraShop')
plt.tight_layout()
plt.show()

# %%
# Quartis: Linhas de Corte da Distribuição
# q1 q2 e q3 obrigatoriamente tem que ser no padrão de 25 50 75
q1 = np.percentile(array_furto, 25)
q2 = np.percentile(array_furto, 50)
q3 = np.percentile(array_furto, 75)

print('q1:' , q1)
print('q2:' , q2)
print('q3:' , q3)
# Out:
# q1: 4002.0
# q2: 6565.5
# q3: 11248.25

# %%
# Aplicando os Quartis na Análise
# Usando .loc
df_top25 = df_cisp_capital.loc[df_cisp_capital['furto_celular'] > q3]
# Usando .query()
df_top25 = df_cisp_capital.query('furto_celular > @q3')

print(df_top25)
# Out:
#     cisp  furto_celular
# 12    16          25709
# 2      5          24695
# 10    14          18286
# 8     12          16929
# 0      1          15952
# 5      9          15009
# 6     10          14571
# 14    18          14047
# 1      4          13992
# 28    32          12623
# 31    35          12092

# %%
# Aplicando os Quartis na Análise
# Usando .loc
df_topmenos25 = df_cisp_capital.loc[df_cisp_capital['furto_celular'] < q1]
# Usando .query()
df_topmenos25 = df_cisp_capital.query('furto_celular > @q1')

#print(df_topmenos25)
df_topmenos25 = df_topmenos25

# %%
'''

Exercício 1

Análise de roubo de veículos por CISP
• Utilizando a variável roubo_veiculos:
• 1. Crie o groupby por CISP com soma e reset_index()
• 2. Ordene do maior para o menor
• 3. Crie o array numpy a partir da coluna roubo_veic
• 4. Calcule e exiba a média e a mediana
• 5. Calcule Q1, Q2 e Q3 em variáveis separadas
• 6. Filtre as CISPs que estão acima de Q3
• Quais CISPs estão nos 25% com mais roubos de veículo?
• Quais CISPs estão nos 25% com menos roubos de veículo?


'''

df_roubo_veiculo_cisp = df.groupby("cisp") ['roubo_veiculos'].sum().reset_index()
df_roubo_veiculo_cisp = df_roubo_veiculo_cisp.sort_values(by="roubo_veiculos", ascending=False)
df_roubo_veiculo_cisp

#maximo = np.max(array_roubo)
#minimo = np.min(array_roubo)
#media = np.mean(array_roubo)
#mediana = np.median(array_roubo)
#q1 = np.percentile(array_roubo, 25)
#q2 = np.percentile(array_roubo, 50)
#q3 = np.percentile(array_roubo, 75)

print(f'O valor máximo é: {maximo}') 
print(f'O valor minimo é: {minimo}')
print(f'A Média é: {media}')
print(f'O Madianar é: {mediana}')
print(f'q1: {q1}')
print(f'q2: {q2}')
print(f'q3: {q3}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[118], line 19
#      15
#      16
#      17 '''
#      18
# ---> 19 df_roubo_veiculo_cisp = df.groupby("cisp") ['roubo_veiculos'].sum().reset_index()
#      20 df_roubo_veiculo_cisp = df_roubo_veiculo_cisp.sort_values(by="roubo_veiculos", ascending=False)
#      21 df_roubo_veiculo_cisp
#      22
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# ...

# %%
'''
Exercício 2

Análise de furto de veículos na Baixada Fluminense
• Filtre os municípios da Baixada Fluminense:
• Com os dados filtrados:
• 1. Crie o groupby por CISP com soma e reset_index() usando furto_veiculo
• 2. Crie o array numpy a partir da coluna furto_veiculo
• 3. Calcule Q1, Q2 e Q3 em variáveis separadas
• 4. Filtre as CISPs acima de Q3
• Quais CISPs da Baixada estão nos 25% com mais furtos de veículo?
• Quais CISPs da Baixada estão nos 25% com menos furtos de veículo
'''

# %%
## .gitignore

## *.csv

## não se deve subir arquivo csv

# %% [markdown]
# 01 Faixa típica de roubo de veículo
#
# Variância e desvio padrão

# %%
array_var = np.array(df['roubo_veiculo'])
media = np.mean(array_var)
variancia= np.var(array_var)
desvio = np.std(array_var)
faixa_inf= media - 2 * desvio
faixa_sup= media + 2 * desvio


print(f'A Média é: {media}')
print(f'Variância: {variancia:.2f}')
print(f'Desvio Padrão: {desvio:.2f}')
print(f'Faixa de Valores: {faixa_inf:.2f} a {faixa_sup:.2f}')
# Out:
# A Média é: 19.12695541130148
# Variância: 1097.19
# Desvio Padrão: 33.12
# Faixa de Valores: -47.12 a 85.37

# %% [markdown]
# 02 Covariância entre ocorrências de veículos
#
# furto_veiculo · roubo_veiculo · recuperacao_veiculo

# %%
a_furto = np.array(df['furto_veiculo'])
a_roubo = np.array(df['roubo_veiculo'])
a_recup = np.array(df['recuperacao_veiculo'])

cov_1 = np.cov_1(df['furto_veiculo'], df['roubo_veiculo'])
cov_1 = matriz_cov[0, 1]
print(f"Covariância: {cov_1:.2f}")

cov_2 = np.cov_1(df['furto_veiculo'], df['recuperacao_veiculo'])
cov_2 = matriz_cov[0, 1]
print(f"Covariância: {cov_2:.2f}")

cov_3 = np.cov_1(df['roubo_veiculo'], df['recuperacao_veiculo'])
cov_3 = matriz_cov[0, 1]
print(f"Covariância: {cov_3:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %% [markdown]
# POWER QUTOMQAATE
# LOW CODE
#
# SALESFORCE
#
# IREI APRENDER MANIPULAÇÃO DE DADOS
#
# PLATAFORMAS DE AUTOMAÇÃO
#
# PYAUTO GUI
#
# SELENIUM
#
# PRECISA DE HTML PARA SELENIUM
#
# PACOTE OFFICE
#
# SQL E BANCO DE DADOS
#
# IA
#
# NO TITULO , PROFISSÃO AD , USAR PIPE COM O QUE EU SEI PY | SQL | ETC
#
# FERRANENTA DE GESTÃO
#
#
# METODOLOGIA AGIL (VER O QUE É) A MAIS COMUM É SCRUM KANBAN E TAMBEM (?BELT)
#
#
# DE PREFERENCIA UM GESTÃO DE PROJETOS
#
#
# VER SSI NO LINKEDIN !!!!!!
