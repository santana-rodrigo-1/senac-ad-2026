# %%
import pandas as pd
import numpy as np

# %%
'''

01 O sistema exportou os pedidos sem calcular o valor total de cada um. 
Corrija isso no DataFrame antes de iniciar qualquer análise.

'''

df = pd.read_csv('pedidos_narashop.csv', sep=';')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 Corrija isso no DataFrame antes de iniciar qualquer análise.
#       5
#       6 '''
#       7
# ----> 8 df = pd.read_csv('pedidos_narashop.csv', sep=';')
#       9 df
#      10
#
# NameError: name 'pd' is not defined

# %%
df.columns
# Out:
# Index(['pedido_id', 'vendedor', 'categoria', 'produto', 'status_pedido',
#        'quantidade', 'valor_unitario', 'prazo_entrega_dias'],
#       dtype='str')

# %%
df['valor_total'] = df['quantidade'] * df['valor_unitario']
df
# Out:
#        pedido_id           vendedor         categoria  \
# 0          10001    Rafael Oliveira          Esportes
# 1          10002       Leandro Reis       Eletrônicos
# 2          10003     Flávia Azevedo       Eletrônicos
# 3          10004      Lucas Ribeiro          Esportes
# 4          10005     Vinícius Lopes       Eletrônicos
# ...          ...                ...               ...
# 19995      29996      Tatiane Cunha          Esportes
# 19996      29997           Ana Lima  Casa e Decoração
# 19997      29998     Patrícia Rocha       Eletrônicos
# 19998      29999  Alexandre Lacerda          Esportes
# 19999      30000      Thiago Santos  Casa e Decoração
#
#                        produto status_pedido  quantidade  valor_unitario  \
# 0      Raquete de Beach Tennis      Entregue           5           98.01
# 1                  SSD Externo      Entregue           4          599.89
# 2                     Notebook      Entregue           5         3774.96
# 3              Garrafa Térmica      Entregue           1           87.67
# 4                  SSD Externo      Entregue           3          439.02
# ...                        ...           ...         ...             ...
# 19995  Raquete de Beach Tennis      Entregue           4          178.86
# 19996              Tapete Sala   Em trânsito           4          166.27
# 19997                   Tablet     Cancelado           5         1577.65
# 19998        Bermuda Esportiva      Entregue           4          144.59
# 19999        Quadro Decorativo   Em trânsito           3           65.70
#
#        prazo_entrega_dias  valor_total
# 0                      12       490.05
# 1                       8      2399.56
# 2                       5     18874.80
# 3                       4        87.67
# 4                       3      1317.06
# ...                   ...          ...
# 19995                   5       715.44
# 19996                   5       665.08
# 19997                   4      7888.25
# 19998                   9       578.36
# 19999                  18       197.10
#
# [20000 rows x 9 columns]

# %%
df.describe()
# Out:
#           pedido_id    quantidade  valor_unitario  prazo_entrega_dias  \
# count  20000.000000  20000.000000    20000.000000        20000.000000
# mean   20000.500000      3.000550      842.816646            8.288750
# std     5773.647028      1.416316     1130.995466            3.973583
# min    10001.000000      1.000000       19.920000            2.000000
# 25%    15000.750000      2.000000      158.202500            5.000000
# 50%    20000.500000      3.000000      295.460000            8.000000
# 75%    25000.250000      4.000000     1210.270000           11.000000
# max    30000.000000      5.000000     5497.320000           18.000000
#
#         valor_total
# count  20000.000000
# mean    2536.787685
# std     3934.278678
# min       19.920000
# 25%      377.745000
# 50%      882.635000
# 75%     2650.950000
# max    27475.250000
